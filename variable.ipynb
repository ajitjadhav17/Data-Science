# %% [markdown]
# # variable

# %% [raw]
# 👉 A variable is like a container (box) that holds a value.

# %%
x = 10

# %%
type(10)
# Out:
# int

# %%
x = 10 
y = 'ajit'

# %%
type(y)
# Out:
# str

# %%
student name ='ajit' # invslid must be _ or not use space
# Out:
#   Cell In[11], line 1
#     student name ='ajit' # invslid must be _ or not use space
#             ^
# SyntaxError: invalid syntax

# %%
z = 'tejas'

# %%
y + z # string arecontact together
# Out:
# 'ajittejas'

# %% [raw]
# # condition
# 1.Must start with a letter or _
# 2.Cannot start with a number

# %% [markdown]
# # Opertion In Python

# %% [raw]
# In Python, operations (operators) are symbols used to perform actions on variables and values

# %%
a=10
b=20

# %%
a+b #both are int + int
# Out:
# 30

# %%
c=1.6

# %%
a+c #int+ float
# Out:
# 11.6

# %%
x= 'hello'

# %%
a + x # int + str are not ok
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 a + x # int + str are not ok
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
y = 'baby'

# %%
x  + y # str + str concate are together
# Out:
# 'hellobaby'

# %%
x + " " + y #space are include due to this
# Out:
# 'hello baby'

# %% [markdown]
# # * F Formating in Python

# %%
 age = 50

# %%
print("my todays age is",age) # we use only (,) so output was clear but this very complicated ,then we are using the f formsting
# Out:
# my todays age is 50

# %% [raw]
# #👉 It means formatted string literal
# # You write f before the string and use {} to include variables.

# %%
name ='ajit'
age = 18 
college_name = 'sinhgad collge'
print(f'my name is {name} age was {age} and collge name is {college_name}')
# Out:
# my name is ajit age was 18 and collge name is sinhgad collge

# %% [markdown]
# # * Type Casting

# %%
age=input('Enter the age')
type(age)
# Out:
# Enter the age 8
# str

# %%
int('25452')
# Out:
# 25452

# %%
type(25452)
# Out:
# int

# %% [markdown]
# # Arithamtic opertor

# %%
a = int(input("Enter rhe first number"))
b = int(input("Enter the second number"))

print(f"adiition of {a} and {b} is {a+b}")
print(f"subtraction of {a} and {b} is {a-b}")
print(f"division of {a} and {b} is {a/b}")
# Out:
# Enter rhe first number 250
# Enter the second number 250
# adiition of 250 and 250 is 500
# subtraction of 250 and 250 is 0
# division of 250 and 250 is 1.0

# %%
print("hello"*4)
# Out:
# hellohellohellohello
