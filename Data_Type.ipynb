# %% [markdown]
# # Data Type

# %% [markdown]
# # 1 Integer

# %%
int(10)
# Out:
# 10

# %% [markdown]
# # 2 float

# %%
float(19.2)
# Out:
# 19.2

# %%
type(19.2)
# Out:
# float

# %% [markdown]
# # 3 String

# %% [raw]
# # used for text data

# %%
str("Ajit jadhav")
# Out:
# 'Ajit jadhav'

# %%
str1("this is my first line
     this is my second line")
# Out:
#   Cell In[8], line 1
#     str1("this is my first line
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
str('''this ismy second linne
this is mysecond line''')
# Out:
# 'this ismy second linne\nthis is mysecond line'

# %% [raw]
# # condition

# %% [raw]
# 1.single line of char ,word ,sentance we use only (" ")or('')
# 2.mulitple sentssnce or writen a paragraph so we use tripple quaote(''' ''')

# %% [markdown]
# # 4 Complex

# %% [raw]
# complex means imaginary number or vector data

# %%
A=(10+10J)

# %%
type(A)
# Out:
# complex

# %% [markdown]
# # 5 Boolean

# %% [raw]
# Used for True/False values
# output --> True/ False

# %%
10 < 20
# Out:
# True

# %%
a=19
b=20.5

# %%
a<b
# Out:
# True
